# %% [markdown]
# ## Document Analysis: Computational Methods - Summer Term 2025
# ### Lectures: Jun.-Prof. Dr. Andreas Spitz
# ### Tutorials: Julian Schelb

# %% [markdown]
# # Exercise 07

# %% [markdown]
# ### You will learn about:

# %% [markdown]
# - Language Models
# - Contextualized Word Embeddings
#
# ---

# %% [markdown]
# ## Task 1: Terminology and Understanding:

# %% [markdown]
# Give a concise answers to each of the following questions.
#
# 1. What is fine-tuning?

# %% [markdown]
# Fine-tuning - the pre-trained model is retrained with less data for a specific application task.

# %% [markdown]
# 2. What is the difference between static and contextualized word embeddings?

# %% [markdown]
# Static word embeddigns - one word = one vector \
# Contextualized word embeddins - vector depends on enviroment

# %% [markdown]
# 3. Explain the purpose of the [SEP] token in BERT.

# %% [markdown]
# [SEP] token in BERT is used to split sentences into segments and then use it for Attention

# %% [markdown]
# ---

# %% [markdown]
# ## Task 2 - Contextualized Word Embeddings
# To avoid issues due to package inconsistencies, please i
#
# ### Part 1:
# Use a pre-trained BERT model to extract word embeddings of the word "bank" from the following seven sentences.
# To extract the embeddings, identify the token that corresponds to "bank" in each sentence
# (keep in mind that token != word), then extract the hidden states for this token from the model's final four
# hidden layers (this is a tensor of dimension 4 x 768).
# Average these four states to obtain a single 768-dimensional embedding for the token "bank" in each sentence.
#
#
# 1. It is good to always have money in the bank.
# 2. A bank of fog came drifting in from the sea.
# 3. Sadly, my piggy bank is empty.
# 4. Gold frequently deposits on the bank of a river.
# 5. Vast banks of clouds were visible on the horizon.
# 6. The First Bank of the United States was chartered in 1791.
# 7. The flight instructor told her to bank hard left.

# %%
# We use bert-base-uncased model from HuggingFace (https://huggingface.co/bert-base-uncased).
from transformers import BertTokenizer, BertModel

# BERT has its own specific tokenizer, you need to use it to tokenize the given sentences
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# And this is the language model; it consists of 12 layers. 
# You need to extract hidden-spaces for the "bank" token from the last four layers and then average them.
model = BertModel.from_pretrained("bert-base-uncased")

# TODO ADD YOUR CODE HERE

# %%
sentences = ["It is good to always have money in the bank.","A bank of fog came drifting in from the sea.","Sadly, my piggy bank is empty.","Gold frequently deposits on the bank of a river.","Vast banks of clouds were visible on the horizon.","The First Bank of the United States was chartered in 1791.","The flight instructor told her to bank hard left."]
tokens = []
embeddings = []

for i in sentences:
    tokens.append(tokenizer.tokenize(i))

for i in tokens:
    embeddings.append(model.resize_token_embeddings(i))

print(tokens)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       6     tokens.append(tokenizer.tokenize(i))
#       8 for i in tokens:
# ----> 9     embeddings.append(model.resize_token_embeddings(i))
#      11 print(tokens)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\modeling_utils.py:3330, in PreTrainedModel.resize_token_embeddings(self, new_num_tokens, pad_to_multiple_of, mean_resizing)
#    3294 def resize_token_embeddings(
#    3295     self,
#    3296     new_num_tokens: Optional[int] = None,
#    3297     pad_to_multiple_of: Optional[int] = None,
#    3298     mean_resizing: bool = True,
#    3299 ) -> nn.Embedding:
#    3300     """
#    3301     Resizes input token embeddings matrix of the model if `new_num_tokens != config.vocab_size`.
#    3302
#    (...)   3328         `torch.nn.Embedding`: Pointer to the input tokens Embeddings Module of the model.
#    3329     """
# -> 3330     model_embeds = self._resize_token_embeddings(new_num_tokens, pad_to_multiple_of, mean_resizing)
#    3331     if new_num_tokens is None and pad_to_multiple_of is None:
#    3332         return model_embeds
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\modeling_utils.py:3355, in PreTrainedModel._resize_token_embeddings(self, new_num_tokens, pad_to_multiple_of, mean_resizing)
#    3353 def _resize_token_embeddings(self, new_num_tokens, pad_to_multiple_of=None, mean_resizing=True):
#    3354     old_embeddings = self.get_input_embeddings()
# -> 3355     new_embeddings = self._get_resized_embeddings(
#    3356         old_embeddings, new_num_tokens, pad_to_multiple_of, mean_resizing
#    3357     )
#    3358     if hasattr(old_embeddings, "_hf_hook"):
#    3359         hook = old_embeddings._hf_hook
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\modeling_utils.py:3482, in PreTrainedModel._get_resized_embeddings(self, old_embeddings, new_num_tokens, pad_to_multiple_of, mean_resizing)
#    3470     raise TypeError(
#    3471         f"Old embeddings are of type {type(old_embeddings)}, which is not an instance of {nn.Embedding}. You"
#    3472         " should either use a different resize function or make sure that `old_embeddings` are an instance of"
#    3473         f" {nn.Embedding}."
#    3474     )
#    3476 # Build new embeddings
#    3477
#    3478 # When using DeepSpeed ZeRO-3, we shouldn't create new embeddings with DeepSpeed init
#    3479 # because the shape of the new embedding layer is used across various modeling files
#    3480 # as well as to update config vocab size. Shape will be 0 when using DeepSpeed init leading
#    3481 # to errors when training.
# -> 3482 new_embeddings = nn.Embedding(
#    3483     new_num_tokens,
#    3484     old_embedding_dim,
#    3485     device=old_embeddings.weight.device,
#    3486     dtype=old_embeddings.weight.dtype,
#    3487 )
#    3489 if new_num_tokens > old_num_tokens and not mean_resizing:
#    3490     # initialize new embeddings (in particular added tokens) with a mean of 0 and std equals `config.initializer_range`.
#    3491     self._init_weights(new_embeddings)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\sparse.py:169, in Embedding.__init__(self, num_embeddings, embedding_dim, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse, _weight, _freeze, device, dtype)
#     166 self.scale_grad_by_freq = scale_grad_by_freq
#     167 if _weight is None:
#     168     self.weight = Parameter(
# --> 169         torch.empty((num_embeddings, embedding_dim), **factory_kwargs),
#     170         requires_grad=not _freeze,
#     171     )
#     172     self.reset_parameters()
#     173 else:
#
# TypeError: empty() received an invalid combination of arguments - got (tuple, dtype=torch.dtype, device=torch.device), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.memory_format memory_format = None, torch.dtype dtype = None, torch.layout layout = None, torch.device device = None, bool pin_memory = False, bool requires_grad = False)
#  * (tuple of ints size, *, torch.memory_format memory_format = None, Tensor out = None, torch.dtype dtype = None, torch.layout layout = None, torch.device device = None, bool pin_memory = False, bool requires_grad = False)

# %% [markdown]
# ---
#
# #### Part 2:
#
# Visualize your results by computing a suitable 2-dimensional projection of the seven embeddings (e.g., by using PCA, t-SNE, or UMAP).
# Make sure that each embedding is labeled clearly in the plot with the sentence number from which you extracted it.

# %%
# You need to use **one** of the dimensionality reduction techniques:

# for PCA use:
# from sklearn.decomposition import PCA

# for t-SNE use:
# from sklearn.manifold import TSNE

# for UMAP first install the package: 
# pip install umap-learn
# import umap

# ADD YOUR CODE HERE

# %% [markdown]
# ---
#
# #### Part 3:
#
# Discuss your findings. Can you explain why some of the embeddings are more similar than others? Do some of the similarities make less sense than others?

# %% [markdown]
# <font color='ff000000'>\# TEXT SUBMISSION ANSWER HERE (Double click to edit) </font>

# %% [markdown]
# ## Task 3 - Sentence Embeddings
# You will analyze the following four sentences:
# 1. If a tree falls in a forest and no one is around to hear it, does it make a sound?
# 2. A tree is an abstract data model consisting of a root, internal nodes, leaves, and path branches.
# 3. In autumn, leaves will slowly fall from the branches towards the roots, covering the path below.
# 4. If a graph is a tree, all node pairs are connected by exactly one path which traverses the root node.
#
# ### Part 1:
# Compute sentence embeddings of the given four sentences with a pre-trained BERT model (use the same model as in Task 2).
# To retrieve sentence embeddings, extract the representation of the [CLS] token from the final layer (i.e., layer 12).

# %%
# TODO - ADD YOUR CODE HERE

# %% [markdown]
# ### Part 2:
# Compute sentence embeddings of the same sentences by averaging the word2vec word embeddings of all words in the sentence (similar to Assignment 6).

# %%
# TODO - ADD YOUR CODE HERE

# %% [markdown]
# ### Part 3:
# Repeat the process described in Part 2, but remove stop words before averaging the word2vec embeddings to create the sentence representation.

# %%
# TODO - ADD YOUR CODE HERE

# %% [markdown]
# ### Part 4:
# Separately compute the pairwise cosine similarities between all four sentence embeddings in each model.
# That is, compute cosine similarities between
#
# (1) all sentence embeddings generated by BERT,
#
# (2) all sentence embeddings generated by word2vec with stop words, and
#
# (3) all sentence embeddings generated by word2vec without stop words
#
# (you **do not** need to compare the embeddings **between different models**!).
#
# Display your results in a table with 5 columns: SentenceID1, SentenceID2, cosine BERT, cosine w2v, cosine w2v-stopwords.

# %%
# TODO - ADD YOUR CODE HERE

# %% [markdown]
# ### Part 5:
# Discuss the results. Which differences in sentence similarities make sense? Can you explain why?

# %% [markdown]
# <font color='ff000000'>\# TEXT SUBMISSION ANSWER HERE (Double click to edit) </font>

# %% [markdown]
# #### Submitting your results:
#
# To submit your results, please:
#
# - save this file, i.e., `ex??_assignment.ipynb`.
# - if you reference any external files (e.g., images), please create a zip or rar archive and put the notebook files and all referenced files in there.
# - login to ILIAS and submit the `*.ipynb` or archive for the corresponding assignment.

# %% [markdown]
# **Remarks:**
#
# - Do not copy any code from the Internet. In case you want to use publicly available code, please, add the reference to the respective code snippet.
# - Check your code compiles and executes, even after you have restarted the Kernel.
# - Submit your written solutions and the coding exercises within the provided spaces and not otherwise.
# - Write the names of your partner and your name in the top section.
